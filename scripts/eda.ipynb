# %%
import pandas as pd
import os
from pandas_profiling import ProfileReport

# %%
data_path = ''

# %%
#df = pd.read_csv('../data/output_2018-04-15.csv')
df = pd.read_csv(data_path)

# %%
df_grouped = df[['OrderID', 'ClientID', 'Interval', 'ChannelID', 'DeliveryType', 'prepay', 'count_edit', 'CancelFlag']].drop_duplicates()

# %%
df_grouped['Interval'].value_counts().plot(kind='bar', figsize=(20,10), fontsize=20)

# %%
df_grouped['ChannelID'].value_counts().plot(kind='bar', figsize=(20,10), fontsize=20, logy=True)

# %%
df['GroupID'].value_counts().plot(kind='bar', figsize=(20,10), fontsize=20, logy=True)

# %%
df['MaterialID'].value_counts()[df['MaterialID'].value_counts() > 50].plot(kind='bar',figsize=(20,10), fontsize=17)

# %%
df['GroupID'].value_counts().plot(kind='bar', figsize=(20,10), fontsize=20, logy=True)
